# %%
input_string = input("Masukkan sebuah string: ")

def semua_substring(s):
    n = len(s)
    substrings = []
    
    for length in range(1, n + 1):  
        for start in range(n - length + 1):  
            substring = s[start:start + length]
            substrings.append(substring)
    
    return substrings

result = semua_substring(input_string)

print("Semua substring:")
for substring in result:
    print(substring)
# Out:
# Semua substring:
# s
# i
# s
# t
# e
# m
#
# i
# n
# f
# o
# r
# m
# a
# s
# i
# si
# is
# st
# te
# em
# m
#  i
# in
# nf
# fo
# or
# rm
# ma
# as
# si
# sis
# ist
# ste
# tem
# em
# m i
#  in
# inf
# nfo
# for
# orm
# rma
# mas
# asi
# sist
# iste
# stem
# tem
# em i
# m in
#  inf
# info
# nfor
# form
# orma
# rmas
# masi
# siste
# istem
# stem
# tem i
# em in
# m inf
#  info
# infor
# nform
# forma
# ormas
# rmasi
# sistem
# istem
# stem i
# tem in
# em inf
# m info
#  infor
# inform
# nforma
# formas
# ormasi
# sistem
# istem i
# stem in
# tem inf
# em info
# m infor
#  inform
# informa
# nformas
# formasi
# sistem i
# istem in
# stem inf
# tem info
# em infor
# m inform
#  informa
# informas
# nformasi
# sistem in
# istem inf
# stem info
# tem infor
# em inform
# m informa
#  informas
# informasi
# sistem inf
# istem info
# stem infor
# tem inform
# em informa
# m informas
#  informasi
# sistem info
# istem infor
# stem inform
# tem informa
# em informas
# m informasi
# sistem infor
# istem inform
# stem informa
# tem informas
# em informasi
# sistem inform
# istem informa
# stem informas
# tem informasi
# sistem informa
# istem informas
# stem informasi
# sistem informas
# istem informasi
# sistem informasi
